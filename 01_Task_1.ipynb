# %% [markdown]
# Section 1 — Practice Questions
# Solve the problems in the code cell below.
#
# Q1. Create a Python list [5, 10, 15, 20, 25].
# Print the 3rd element and the last element.
#
# Q2. Write a loop that prints the square of each number in [1, 2, 3, 4, 5].
# Then rewrite the same thing using a list comprehension in one line.
#
# Q3. Convert the list [3, 6, 9, 12, 15] to a NumPy array.
# Multiply every element by 4 using a single operation (no loop).

# %%
#Q.1.
my_list = [5,10,15,20,25]
print("Third element of a list:",my_list[3])
print("Last element of a list:",my_list[-1])
# Out:
# Third element of a list: 20
# Last element of a list: 25

# %%
#Q.2.
for num in [1,2,3,4,5]:
  square = 2*num
  print("Square of each number:",square)
# Out:
# Square of each number: 2
# Square of each number: 4
# Square of each number: 6
# Square of each number: 8
# Square of each number: 10

# %%
#Q.3.
squares = [num**2 for num in [1,2,3,4,5]]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
#Q.3.
import numpy as np
numbers = [3,6,9,12,15]
arr = np.array(numbers)
result = arr*4
print(result)
# Out:
# [12 24 36 48 60]
